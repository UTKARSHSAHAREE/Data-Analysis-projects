# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/utkarshsahare/intro-to-stats/IBM-313 Marks.xlsx
# /kaggle/input/datasets/utkarshsahare/plotting/GOOG.csv

# %%
df=pd.read_excel('/kaggle/input/datasets/utkarshsahare/intro-to-stats/IBM-313 Marks.xlsx')

# %%
df.head()
# Out:
#    S.No.  MTE (25)  Mini Project (25)  Total (50)  ETE (50)  Total
# 0      1      5.00                 20       25.00      12.0  37.00
# 1      2     11.05                 20       31.05      26.0  57.05
# 2      3      8.10                 20       28.10      14.0  42.10
# 3      4      6.00                 10       16.00      13.0  29.00
# 4      5     11.35                 20       31.35      17.0  48.35

# %% [markdown]
# ### mean

# %%
x=df['Total']
np.mean(x)
# Out:
# np.float64(46.90632911392405)

# %% [markdown]
# ### median

# %%
np.median(x)
# Out:
# np.float64(45.0)

# %%
#np.mode(x)

# %%
from scipy import stats
stats.mode(x)
# Out:
# ModeResult(mode=np.float64(0.0), count=np.int64(2))

# %% [markdown]
# ### percentile

# %%
a=np.array([1,2,3,4,5])
p=np.percentile(a,50)
print(p)
# Out:
# 3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              79 non-null     int64
#  1   MTE (25)           79 non-null     float64
#  2   Mini Project (25)  79 non-null     int64
#  3   Total (50)         79 non-null     float64
#  4   ETE (50)           77 non-null     float64
#  5   Total              79 non-null     float64
# dtypes: float64(4), int64(2)
# memory usage: 3.8 KB

# %%
df.describe()
# Out:
#            S.No.   MTE (25)  Mini Project (25)  Total (50)   ETE (50)  \
# count  79.000000  79.000000          79.000000   79.000000  77.000000
# mean   40.000000  10.178481          16.556962   26.735443  21.016234
# std    22.949219   4.961924           4.900934    8.504976   8.091209
# min     1.000000   0.700000          10.000000   11.200000   7.000000
# 25%    20.500000   6.500000          11.000000   19.600000  17.000000
# 50%    40.000000  10.300000          15.000000   27.500000  20.000000
# 75%    59.500000  12.975000          22.000000   33.250000  24.000000
# max    79.000000  23.500000          22.000000   45.500000  50.000000
#
#            Total
# count  79.000000
# mean   46.906329
# std    16.314119
# min     0.000000
# 25%    38.000000
# 50%    45.000000
# 75%    55.375000
# max    94.500000

# %%
import seaborn as sns

# %%
df.columns
# Out:
# Index(['S.No.', 'MTE (25)', 'Mini Project (25)', 'Total (50)', 'ETE (50)',
#        'Total'],
#       dtype='object')

# %%
df.shape
# Out:
# (79, 6)

# %%
sns.barplot(data=df,x='ETE (50)',hue='ETE (50)')
# Out:
# <Axes: xlabel='ETE (50)'>

# %%
sns.countplot(data=df,x='ETE (50)')
# Out:
# <Axes: xlabel='ETE (50)', ylabel='count'>

# %%
df.columns
# Out:
# Index(['S.No.', 'MTE (25)', 'Mini Project (25)', 'Total (50)', 'ETE (50)',
#        'Total'],
#       dtype='object')

# %%
sns.displot(data=df,y='ETE (50)',x='S.No.',hue='ETE (50)',kind='hist')

# %%
sns.histplot(data=df,y='ETE (50)',x='S.No.')
# Out:
# <Axes: xlabel='S.No.', ylabel='ETE (50)'>

# %%
for i in df.columns:
    range=max(df[i])-min(df[i])
    print(f'range of {i} is {range}')
# Out:
# range of S.No. is 78
# range of MTE (25) is 22.8
# range of Mini Project (25) is 12
# range of Total (50) is 34.3
# range of ETE (50) is 43.0
# range of Total is 94.5

# %%
a=np.array([1,2,3,4,5])
q1=np.percentile(a,25)
print(int(q1))
# Out:
# 2

# %% [markdown]
# ### **25% of data is  at and below 2**

# %%
a=np.array([1,2,3,4,5])
q2=np.percentile(a,50)
print(int(q2))
# Out:
# 3

# %% [markdown]
# ### **50% of data is  at and below 3**

# %%
a=np.array([1,2,3,4,5])
q3=np.percentile(a,75)
print(int(q3))
# Out:
# 4

# %% [markdown]
# ### **75% of data is  at and below 4**

# %% [markdown]
# ## Inter Quartile Range

# %%
IQ = q3-q1
print(int(IQ))
# Out:
# 2

# %%
print(a)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# ## **Variance** : sample variance

# %%
np.mean(a)
# Out:
# np.float64(3.0)

# %%
np.var(a)
# Out:
# np.float64(2.0)

# %%
int(np.var(x))
# Out:
# 262

# %%
import statistics as stat
int(stat.pstdev(x))
# Out:
# 16

# %% [markdown]
# ## Sample Standard Deviation

# %%
stat.stdev(x)
# Out:
# 16.31411880088133

# %% [markdown]
# ## Population Standard Deviation

# %%
np.std(x)
# Out:
# 16.210536046955966

# %% [markdown]
# ## skewnwss

# %%
from scipy.stats import skew

# %%
skew(x)
# Out:
# np.float64(0.10226407464884266)

# %% [markdown]
# ## boxplot

# %%
from matplotlib import pyplot as plt
plt.boxplot(x,sym="+")
plt.show()
